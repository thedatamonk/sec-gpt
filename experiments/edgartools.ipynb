# %% [markdown]
# # Financial Analysis
# - Compare companies across industries
# - Track financial performance over time
# - Calculate and analyze financial ratios
# - Build custom financial dashboards

# %%
from edgar import *

# %%
set_identity("rohilpal9763@gmail.com")

# %% [markdown]
# # Core objects
#
# 1. Company
#     - The Company class is the primary interface for working with public companies in EdgarTools. It provides access to company information, SEC filings, and financial data.
# 2. Filings
# 3. Filing
#     - The Filing class represents a single SEC filing and provides access to its documents, data, and metadata. It serves as the foundation for all filing-related operations in EdgarTools.
#
# 4. XBRL

# %% [markdown]
# ## Company API reference
#
# 1. Company object can be fetched from edgar using cik or ticker (case insensitive).
# 2. Company object can have one or more ticker names. These can be fetched using `company.tickers`
# 3. Get filings for a company object.
# 4. Get financials
# 5. Get quarterly financials
# 6. Get Facts
# 7. Get Latest filing

# %%
config = {
    "ticker_name": "NVDA",
}

company = Company(cik_or_ticker=config["ticker_name"])

# %%
# Get properties of the class
def list_properties(cls):
    properties = []
    for name in dir(cls):
        # We need to check the class's __dict__ directly to find property objects
        # because dir() also lists methods and other attributes.
        attr = getattr(cls, name, None)
        if isinstance(attr, property):
            properties.append(name)
    return properties

company_meta_props = list_properties(Company)


for prop_name in company_meta_props:
    try:
        # Use getattr to safely access the property value
        prop_value = getattr(company, prop_name)
        print(f"  {prop_name}: {prop_value}")
    except AttributeError:
        # This might happen if a property's getter raises an error
        # or if there's some unexpected issue (less common for basic properties)
        print(f"  {prop_name}: Could not retrieve value (AttributeError)")
    except Exception as e:
        # Catch other potential exceptions during property access
        print(f"  {prop_name}: Error retrieving value - {e}")

# %%
from ollama import chat

messages = [
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
]

for part in chat('llama3:instruct', messages=messages, stream=True):
  print(part['message']['content'], end='', flush=True)
# Out:
# What a great question! The sky appears blue to our eyes because of a phenomenon called Rayleigh scattering. This is when shorter, blue wavelengths of light are scattered in all directions by tiny molecules of gases in the atmosphere, such as nitrogen and oxygen.
#
# Here's how it works:
#
# 1. Sunlight enters Earth's atmosphere and contains all the colors of the visible spectrum (red, orange, yellow, green, blue, indigo, and violet).
# 2. When this light encounters the small molecules of gases in the air, the shorter wavelengths (like blue and violet) are scattered more than the longer wavelengths (like red and orange). This is because the smaller molecules are better at scattering shorter wavelengths.
# 3. As a result, our eyes see the scattered blue light as the dominant color, giving the sky its blue appearance.
#
# This effect is not unique to Earth; it's also why sunsets often appear reddish-orange. When the sun is lower in the sky, it has to travel through more of the atmosphere to reach us, which means there's even more scattering of shorter wavelengths (like blue and violet). This leaves mostly longer wavelengths (like red and orange) to reach our eyes, making the sunset appear more orange or reddish.
#
# It's worth noting that the exact shade of blue can vary depending on atmospheric conditions like pollution levels, dust particles, and water vapor. But in general, Rayleigh scattering is the main reason why the sky appears blue to us!

# %%
import requests

ticker_to_cik = {}
name_to_cik = {}
cik_to_metadata = {}


"""
Fetches and processes the company ticker and CIK data from the SEC.
This data will be used to verify entities identified by the LLM.
"""
    
SEC_COMPANY_TICKERS_URL = "https://www.sec.gov/files/company_tickers.json"

print("Loading company data from SEC...")

response = requests.get(SEC_COMPANY_TICKERS_URL, headers={"User-Agent": "rohilpal9763@gmail.com"})
response.raise_for_status()
all_companies = response.json()
for company_data in all_companies.values():
    cik_str = str(company_data['cik_str']).zfill(10)
    ticker = company_data['ticker']
    name = company_data['title']
    if cik_str in cik_to_metadata.keys():
        # We are doing this because the same CIK/company can have multiple ticker names 
        cik_to_metadata[cik_str]["ticker"].append(ticker)
    else:
        cik_to_metadata[cik_str] = {}
        cik_to_metadata[cik_str]["name"] = name
        cik_to_metadata[cik_str]["cik"] = cik_str
        cik_to_metadata[cik_str]["ticker"] = [ticker]
    
    ticker_to_cik[ticker.lower()] = cik_str
    name_to_cik[name.lower()] = cik_str
print(f"Successfully loaded data for {len(cik_to_metadata)} companies.")
# Out:
# Loading company data from SEC...
# Successfully loaded data for 7869 companies.

# %%
print (f"`cik_to_metadata`: {len(cik_to_metadata)}")
print (f"`ticker_to_cik`: {len(ticker_to_cik)}")
print (f"`name_to_cik`: {len(name_to_cik)}")
# Out:
# `cik_to_metadata`: 7869
# `ticker_to_cik`: 10090
# `name_to_cik`: 7869

# %% [markdown]
# ### Conclusion
#
# Same company name and cik can have multiple ticker names

# %%
for cik, company_info in cik_to_metadata.items():
    if len(set(company_info["ticker"])) > 1:
        print ("--"*30 + "\n")
        print (f"CIK: {cik}")
        print (f"Company info: {company_info}")
        print ("--"*30 + "\n")
# Out:
# ------------------------------------------------------------
#
# CIK: 0001652044
# Company info: {'name': 'Alphabet Inc.', 'cik': '0001652044', 'ticker': ['GOOGL', 'GOOG']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001067983
# Company info: {'name': 'BERKSHIRE HATHAWAY INC', 'cik': '0001067983', 'ticker': ['BRK-B', 'BRK-A']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000019617
# Company info: {'name': 'JPMORGAN CHASE & CO', 'cik': '0000019617', 'ticker': ['JPM', 'JPM-PC', 'JPM-PD', 'JPM-PJ', 'JPM-PK', 'JPM-PL', 'JPM-PM', 'VYLD', 'AMJB']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000070858
# Company info: {'name': 'BANK OF AMERICA CORP /DE/', 'cik': '0000070858', 'ticker': ['BAC', 'BML-PG', 'BML-PH', 'BAC-PE', 'BML-PL', 'BAC-PB', 'BML-PJ', 'BAC-PK', 'BAC-PL', 'BAC-PM', 'MER-PK', 'BAC-PN', 'BAC-PO', 'BAC-PP', 'BAC-PQ', 'BAC-PS', 'BACRP']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001000184
# Company info: {'name': 'SAP SE', 'cik': '0001000184', 'ticker': ['SAP', 'SAPGF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000937966
# Company info: {'name': 'ASML HOLDING NV', 'cik': '0000937966', 'ticker': ['ASML', 'ASMLF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001577552
# Company info: {'name': 'Alibaba Group Holding Ltd', 'cik': '0001577552', 'ticker': ['BABA', 'BABAF', 'BBAAY']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001283699
# Company info: {'name': 'T-Mobile US, Inc.', 'cik': '0001283699', 'ticker': ['TMUS', 'TMUSI', 'TMUSL', 'TMUSZ']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000072971
# Company info: {'name': 'WELLS FARGO & COMPANY/MN', 'cik': '0000072971', 'ticker': ['WFC', 'WFC-PY', 'WFC-PL', 'WFC-PC', 'WFC-PD', 'WFC-PZ', 'WFCNP', 'WFC-PA']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000353278
# Company info: {'name': 'NOVO NORDISK A S', 'cik': '0000353278', 'ticker': ['NVO', 'NONOF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001094517
# Company info: {'name': 'TOYOTA MOTOR CORP/', 'cik': '0001094517', 'ticker': ['TM', 'TOYOF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000901832
# Company info: {'name': 'ASTRAZENECA PLC', 'cik': '0000901832', 'ticker': ['AZN', 'AZNCF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001114448
# Company info: {'name': 'NOVARTIS AG', 'cik': '0001114448', 'ticker': ['NVS', 'NVSEF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000895421
# Company info: {'name': 'MORGAN STANLEY', 'cik': '0000895421', 'ticker': ['MS', 'MS-PA', 'MS-PK', 'MS-PI', 'MS-PF', 'MS-PE', 'MS-PL', 'MSTLW', 'MS-PQ', 'MS-PO', 'MS-PP']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000886982
# Company info: {'name': 'GOLDMAN SACHS GROUP INC', 'cik': '0000886982', 'ticker': ['GS', 'GS-PA', 'GS-PD', 'GS-PC', 'GSCE']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001089113
# Company info: {'name': 'HSBC HOLDINGS PLC', 'cik': '0001089113', 'ticker': ['HSBC', 'HBCYF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001306965
# Company info: {'name': 'Shell plc', 'cik': '0001306965', 'ticker': ['SHEL', 'RYDAF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000732717
# Company info: {'name': 'AT&T INC.', 'cik': '0000732717', 'ticker': ['T', 'TBB', 'T-PA', 'T-PC']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001000275
# Company info: {'name': 'ROYAL BANK OF CANADA', 'cik': '0001000275', 'ticker': ['RY', 'RBMCF', 'RYLBF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0002070829
# Company info: {'name': 'Contemporary Amperex Technology Co., Limited/ADR', 'cik': '0002070829', 'ticker': ['CYATY', 'CTATF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000946770
# Company info: {'name': 'DEUTSCHE TELEKOM AG', 'cik': '0000946770', 'ticker': ['DTEGY', 'DTEGF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000831001
# Company info: {'name': 'CITIGROUP INC', 'cik': '0000831001', 'ticker': ['C', 'C-PN']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000012927
# Company info: {'name': 'BOEING CO', 'cik': '0000012927', 'ticker': ['BA', 'BA-PA']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000316709
# Company info: {'name': 'SCHWAB CHARLES CORP', 'cik': '0000316709', 'ticker': ['SCHW', 'SCHW-PD', 'SCHW-PJ']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000067088
# Company info: {'name': 'MITSUBISHI UFJ FINANCIAL GROUP INC', 'cik': '0000067088', 'ticker': ['MUFG', 'MBFJF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000313838
# Company info: {'name': 'Sony Group Corp', 'cik': '0000313838', 'ticker': ['SONY', 'SNEJF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000217410
# Company info: {'name': 'UNILEVER PLC', 'cik': '0000217410', 'ticker': ['UL', 'UNLYF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000753308
# Company info: {'name': 'NEXTERA ENERGY INC', 'cik': '0000753308', 'ticker': ['NEE', 'NEE-PN', 'NEE-PT', 'NEE-PU', 'NEE-PR', 'NEE-PS']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000927628
# Company info: {'name': 'CAPITAL ONE FINANCIAL CORP', 'cik': '0000927628', 'ticker': ['COF', 'COF-PI', 'COF-PJ', 'COF-PK', 'COF-PL', 'COF-PN']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000811809
# Company info: {'name': 'BHP Group Ltd', 'cik': '0000811809', 'ticker': ['BHP', 'BHPLF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000891478
# Company info: {'name': 'Banco Santander, S.A.', 'cik': '0000891478', 'ticker': ['SAN', 'BCDRF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000879764
# Company info: {'name': 'TotalEnergies SE', 'cik': '0000879764', 'ticker': ['TTE', 'TTFNF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000947263
# Company info: {'name': 'TORONTO DOMINION BANK', 'cik': '0000947263', 'ticker': ['TD', 'TDBCP', 'TDOMF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001404912
# Company info: {'name': 'KKR & Co. Inc.', 'cik': '0001404912', 'ticker': ['KKR', 'KKRS', 'KKRT', 'KKR-PD']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001303523
# Company info: {'name': 'British American Tobacco p.l.c.', 'cik': '0001303523', 'ticker': ['BTI', 'BTAFF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000047710
# Company info: {'name': 'HITACHI LTD', 'cik': '0000047710', 'ticker': ['HTHIY', 'HTHIF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001166691
# Company info: {'name': 'COMCAST CORP', 'cik': '0001166691', 'ticker': ['CMCSA', 'CCZ']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001668717
# Company info: {'name': 'Anheuser-Busch InBev SA/NV', 'cik': '0001668717', 'ticker': ['BUD', 'BUDFF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001121404
# Company info: {'name': 'Sanofi', 'cik': '0001121404', 'ticker': ['SNY', 'SNYNF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001022837
# Company info: {'name': 'SUMITOMO MITSUI FINANCIAL GROUP, INC.', 'cik': '0001022837', 'ticker': ['SMFG', 'SMFNF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001045609
# Company info: {'name': 'Prologis, Inc.', 'cik': '0001045609', 'ticker': ['PLD', 'PLDGP']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000895728
# Company info: {'name': 'ENBRIDGE INC', 'cik': '0000895728', 'ticker': ['ENB', 'EBBNF', 'EBGEF', 'EBRGF', 'EBRZF', 'ENBFF', 'EBBGF', 'ENBMF', 'ENBOF', 'ENBSF', 'ENBNF', 'ENBHF', 'ENBGF', 'ENBRF', 'ENNPF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000842180
# Company info: {'name': 'BANCO BILBAO VIZCAYA ARGENTARIA, S.A.', 'cik': '0000842180', 'ticker': ['BBVA', 'BBVXF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000092122
# Company info: {'name': 'SOUTHERN CO', 'cik': '0000092122', 'ticker': ['SO', 'SOJC', 'SOJD', 'SOJE', 'SOJF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000948401
# Company info: {'name': 'COMPAGNIE FINANCIERE RICHEMONT AG /FI', 'cik': '0000948401', 'ticker': ['CFRUY', 'CFRHF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000863064
# Company info: {'name': 'RIO TINTO PLC', 'cik': '0000863064', 'ticker': ['RIO', 'RTPPF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001001085
# Company info: {'name': 'BROOKFIELD Corp /ON/', 'cik': '0001001085', 'ticker': ['BN', 'BAMGF', 'BAMKF', 'BKAMF', 'BKFAF', 'BKFPF', 'BKPA', 'BKFDF', 'BKFSF', 'BKFOF', 'BRPSF', 'BRFCF', 'BNH', 'BNJ', 'BROXF', 'BXDIF', 'BRCFF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001050446
# Company info: {'name': 'Strategy Inc', 'cik': '0001050446', 'ticker': ['MSTR', 'STRC', 'STRF', 'STRK', 'STRD']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000014272
# Company info: {'name': 'BRISTOL MYERS SQUIBB CO', 'cik': '0000014272', 'ticker': ['BMY', 'BMYMP', 'CELG-RI']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001326160
# Company info: {'name': 'Duke Energy CORP', 'cik': '0001326160', 'ticker': ['DUK', 'DUK-PA', 'DUKH', 'DUKB']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000313807
# Company info: {'name': 'BP PLC', 'cik': '0000313807', 'ticker': ['BP', 'BPAQF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000929869
# Company info: {'name': 'RELX PLC', 'cik': '0000929869', 'ticker': ['RELX', 'RLXXF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000927971
# Company info: {'name': 'BANK OF MONTREAL /CAN/', 'cik': '0000927971', 'ticker': ['BMO', 'FNGD', 'FNGO', 'FNGS', 'FNGU', 'GDXD', 'DULL', 'FLYD', 'FLYU', 'BERZ', 'BNKD', 'BNKU', 'BULZ', 'JETU', 'JETD', 'CARD', 'CARU', 'SHNY', 'WTID', 'WTIU', 'GDXU', 'NRGD', 'NRGU', 'OILD', 'OILU']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001110646
# Company info: {'name': 'NetEase, Inc.', 'cik': '0001110646', 'ticker': ['NTES', 'NETTF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001335730
# Company info: {'name': 'MIZUHO FINANCIAL GROUP INC', 'cik': '0001335730', 'ticker': ['MFG', 'MZHOF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001131399
# Company info: {'name': 'GSK plc', 'cik': '0001131399', 'ticker': ['GSK', 'GLAXF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001164727
# Company info: {'name': 'NEWMONT Corp /DE/', 'cik': '0001164727', 'ticker': ['NEM', 'NEMCL']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001075124
# Company info: {'name': 'THOMSON REUTERS CORP /CAN/', 'cik': '0001075124', 'ticker': ['TRI', 'TMSOF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001858681
# Company info: {'name': 'Apollo Global Management, Inc.', 'cik': '0001858681', 'ticker': ['APO', 'APO-PA', 'APOS']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0002039784
# Company info: {'name': 'Midea Group Co., Ltd./ADR', 'cik': '0002039784', 'ticker': ['MGCLY', 'MGCOF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001119639
# Company info: {'name': 'PETROBRAS - PETROLEO BRASILEIRO SA', 'cik': '0001119639', 'ticker': ['PBR', 'PBR-A']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000036104
# Company info: {'name': 'US BANCORP \\DE\\', 'cik': '0000036104', 'ticker': ['USB', 'USB-PA', 'USB-PH', 'USB-PP', 'USB-PQ', 'USB-PR', 'USB-PS']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001390777
# Company info: {'name': 'Bank of New York Mellon Corp', 'cik': '0001390777', 'ticker': ['BK', 'BK-PK']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001039765
# Company info: {'name': 'ING GROEP NV', 'cik': '0001039765', 'ticker': ['ING', 'INGVF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001004315
# Company info: {'name': 'NATIONAL GRID PLC', 'cik': '0001004315', 'ticker': ['NGG', 'NGGTF', 'NMKCP', 'NMKBP', 'NMPWP', 'NEWEN']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000004281
# Company info: {'name': 'Howmet Aerospace Inc.', 'cik': '0000004281', 'ticker': ['HWM', 'HWM-P']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000312069
# Company info: {'name': 'BARCLAYS PLC', 'cik': '0000312069', 'ticker': ['BCS', 'BCLYF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000895564
# Company info: {'name': 'BAE SYSTEMS PLC /FI/', 'cik': '0000895564', 'ticker': ['BAESY', 'BAESF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001061219
# Company info: {'name': 'ENTERPRISE PRODUCTS PARTNERS L.P.', 'cik': '0001061219', 'ticker': ['EPD', 'EPDU']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001159508
# Company info: {'name': 'DEUTSCHE BANK AKTIENGESELLSCHAFT', 'cik': '0001159508', 'ticker': ['DB', 'DGP', 'DGZ', 'DEENF', 'ADZCF', 'DZZ', 'OLOXF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001063761
# Company info: {'name': 'SIMON PROPERTY GROUP INC /DE/', 'cik': '0001063761', 'ticker': ['SPG', 'SPG-PJ']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001160106
# Company info: {'name': 'Lloyds Banking Group plc', 'cik': '0001160106', 'ticker': ['LYG', 'LLDTF', 'LLOBF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001446250
# Company info: {'name': 'Bayerische Motoren Werke AG/ADR', 'cik': '0001446250', 'ticker': ['BMWKY', 'BAMXF', 'BYMOF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000835403
# Company info: {'name': 'DIAGEO PLC', 'cik': '0000835403', 'ticker': ['DEO', 'DGEAF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001140625
# Company info: {'name': 'EQUINOR ASA', 'cik': '0001140625', 'ticker': ['EQNR', 'STOHF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001129137
# Company info: {'name': 'AMERICA MOVIL SAB DE CV/', 'cik': '0001129137', 'ticker': ['AMX', 'AMXOF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001276187
# Company info: {'name': 'Energy Transfer LP', 'cik': '0001276187', 'ticker': ['ET', 'ET-PI']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000092230
# Company info: {'name': 'TRUIST FINANCIAL CORP', 'cik': '0000092230', 'ticker': ['TFC', 'TFC-PI', 'TFC-PO', 'TFC-PR']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001506307
# Company info: {'name': 'KINDER MORGAN, INC.', 'cik': '0001506307', 'ticker': ['KMI', 'EP-PC']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000844150
# Company info: {'name': 'NatWest Group plc', 'cik': '0000844150', 'ticker': ['NWG', 'RBSPF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001176948
# Company info: {'name': 'Ares Management Corp', 'cik': '0001176948', 'ticker': ['ARES', 'ARES-PB']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001297996
# Company info: {'name': 'DIGITAL REALTY TRUST, INC.', 'cik': '0001297996', 'ticker': ['DLR', 'DLR-PK', 'DLR-PJ', 'DLR-PL']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001158838
# Company info: {'name': 'ADVANTEST CORP', 'cik': '0001158838', 'ticker': ['ATEYY', 'ADTTF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001107457
# Company info: {'name': 'INFINEON TECHNOLOGIES AG', 'cik': '0001107457', 'ticker': ['IFNNY', 'IFNNF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001099219
# Company info: {'name': 'METLIFE INC', 'cik': '0001099219', 'ticker': ['MET', 'MET-PA', 'MET-PE', 'MET-PF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001002242
# Company info: {'name': 'ENI SPA', 'cik': '0001002242', 'ticker': ['E', 'EIPAF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000899051
# Company info: {'name': 'ALLSTATE CORP', 'cik': '0000899051', 'ticker': ['ALL', 'ALL-PH', 'ALL-PB', 'ALL-PI', 'ALL-PJ']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001032208
# Company info: {'name': 'SEMPRA', 'cik': '0001032208', 'ticker': ['SRE', 'SREA']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001232384
# Company info: {'name': 'TC ENERGY CORP', 'cik': '0001232384', 'ticker': ['TRP', 'TNCAF', 'TCANF', 'TCNCF', 'TRPRF', 'TCEYF', 'TRPPF', 'TRPEF', 'TCENF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001086888
# Company info: {'name': 'MANULIFE FINANCIAL CORP', 'cik': '0001086888', 'ticker': ['MFC', 'MNLCF', 'MNQFF', 'MNUFF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001552000
# Company info: {'name': 'MPLX LP', 'cik': '0001552000', 'ticker': ['MPLX', 'MPLXP']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001393311
# Company info: {'name': 'Public Storage', 'cik': '0001393311', 'ticker': ['PSA', 'PSA-PH', 'PSA-PK', 'PSA-PI', 'PSA-PJ', 'PSA-PF', 'PSA-PG', 'PSA-PL', 'PSA-PM', 'PSA-PN', 'PSA-PO', 'PSA-PP', 'PSA-PQ', 'PSA-PR', 'PSA-PS']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001512673
# Company info: {'name': 'Block, Inc.', 'cik': '0001512673', 'ticker': ['XYZ', 'BSQKZ']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001547873
# Company info: {'name': 'PT Chandra Asri Petrochemical Tbk/ADR', 'cik': '0001547873', 'ticker': ['PTCAY', 'PTPIF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001136808
# Company info: {'name': 'E.ON SE', 'cik': '0001136808', 'ticker': ['EONGY', 'ENAKF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000037996
# Company info: {'name': 'FORD MOTOR CO', 'cik': '0000037996', 'ticker': ['F', 'F-PB', 'F-PC', 'F-PD']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001395064
# Company info: {'name': 'TAKEDA PHARMACEUTICAL CO LTD', 'cik': '0001395064', 'ticker': ['TAK', 'TKPHF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000797468
# Company info: {'name': 'OCCIDENTAL PETROLEUM CORP /DE/', 'cik': '0000797468', 'ticker': ['OXY', 'OXY-WT']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000715153
# Company info: {'name': 'HONDA MOTOR CO LTD', 'cik': '0000715153', 'ticker': ['HMC', 'HNDAF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001549802
# Company info: {'name': 'JD.com, Inc.', 'cik': '0001549802', 'ticker': ['JD', 'JDCMF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001900304
# Company info: {'name': 'Haleon plc', 'cik': '0001900304', 'ticker': ['HLN', 'HLNCF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001269238
# Company info: {'name': 'Trip.com Group Ltd', 'cik': '0001269238', 'ticker': ['TCOM', 'TRPCF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000943819
# Company info: {'name': 'RESMED INC', 'cik': '0000943819', 'ticker': ['RMD', 'RSMDF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0002021390
# Company info: {'name': 'Galderma Group AG/ADR', 'cik': '0002021390', 'ticker': ['GALDY', 'GDERF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001744676
# Company info: {'name': 'Tencent Music Entertainment Group', 'cik': '0001744676', 'ticker': ['TME', 'TCMEF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000046619
# Company info: {'name': 'HEICO CORP', 'cik': '0000046619', 'ticker': ['HEI', 'HEI-A']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001137774
# Company info: {'name': 'PRUDENTIAL FINANCIAL INC', 'cik': '0001137774', 'ticker': ['PRU', 'PFH', 'PRH', 'PRS']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000915191
# Company info: {'name': 'FAIRFAX FINANCIAL HOLDINGS LTD/ CAN', 'cik': '0000915191', 'ticker': ['FRFHF', 'FAXXF', 'FRFFF', 'FRFXF', 'FAXRF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001125259
# Company info: {'name': 'CARNIVAL PLC', 'cik': '0001125259', 'ticker': ['CUK', 'CUKPF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000874766
# Company info: {'name': 'HARTFORD INSURANCE GROUP, INC.', 'cik': '0000874766', 'ticker': ['HIG', 'HIG-PG']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000850918
# Company info: {'name': 'GREAT-WEST LIFECO INC.', 'cik': '0000850918', 'ticker': ['GWLIF', 'GRWLF', 'GRWTF', 'GWLPF', 'GRWFF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001651308
# Company info: {'name': 'BeOne Medicines Ltd.', 'cik': '0001651308', 'ticker': ['ONC', 'BEIGF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000827054
# Company info: {'name': 'MICROCHIP TECHNOLOGY INC', 'cik': '0000827054', 'ticker': ['MCHP', 'MCHPP']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000920760
# Company info: {'name': 'LENNAR CORP /NEW/', 'cik': '0000920760', 'ticker': ['LEN', 'LEN-B']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000947484
# Company info: {'name': 'ARCH CAPITAL GROUP LTD.', 'cik': '0000947484', 'ticker': ['ACGL', 'ACGLO', 'ACGLN']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001116578
# Company info: {'name': 'PRUDENTIAL PLC', 'cik': '0001116578', 'ticker': ['PUK', 'PUKPF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000844551
# Company info: {'name': 'WOODSIDE ENERGY GROUP LTD', 'cik': '0000844551', 'ticker': ['WDS', 'WOPEF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000720005
# Company info: {'name': 'RAYMOND JAMES FINANCIAL INC', 'cik': '0000720005', 'ticker': ['RJF', 'RJF-PB']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001038683
# Company info: {'name': 'RYANAIR HOLDINGS PLC', 'cik': '0001038683', 'ticker': ['RYAAY', 'RYAOF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001004980
# Company info: {'name': 'PG&E Corp', 'cik': '0001004980', 'ticker': ['PCG', 'PCG-PA', 'PCG-PB', 'PCG-PE', 'PCG-PD', 'PCG-PC', 'PCG-PH', 'PCG-PG', 'PCG-PI', 'PCG-PX']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000093751
# Company info: {'name': 'STATE STREET CORP', 'cik': '0000093751', 'ticker': ['STT', 'STT-PG']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001097362
# Company info: {'name': 'SUN LIFE FINANCIAL INC', 'cik': '0001097362', 'ticker': ['SLF', 'SLFIF', 'SUNFF', 'SLFQF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000036270
# Company info: {'name': 'M&T BANK CORP', 'cik': '0000036270', 'ticker': ['MTB', 'MTB-PJ', 'MTB-PH']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001475260
# Company info: {'name': 'CENOVUS ENERGY INC.', 'cik': '0001475260', 'ticker': ['CVE', 'CVE-WT', 'CNVEF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001329099
# Company info: {'name': 'Baidu, Inc.', 'cik': '0001329099', 'ticker': ['BIDU', 'BAIDF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000814052
# Company info: {'name': 'TELEFONICA S A', 'cik': '0000814052', 'ticker': ['TEF', 'TEFOF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000035527
# Company info: {'name': 'FIFTH THIRD BANCORP', 'cik': '0000035527', 'ticker': ['FITB', 'FITBI', 'FITBO', 'FITBP']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000861967
# Company info: {'name': 'WOLTERS KLUWER N V /FI', 'cik': '0000861967', 'ticker': ['WTKWY', 'WOLTF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001645590
# Company info: {'name': 'Hewlett Packard Enterprise Co', 'cik': '0001645590', 'ticker': ['HPE', 'HPE-PC']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001160330
# Company info: {'name': 'BANK BRADESCO', 'cik': '0001160330', 'ticker': ['BBD', 'BBDO']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001172724
# Company info: {'name': 'GOLD FIELDS LTD', 'cik': '0001172724', 'ticker': ['GFI', 'GFIOF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000839923
# Company info: {'name': 'VODAFONE GROUP PUBLIC LTD CO', 'cik': '0000839923', 'ticker': ['VOD', 'VODPF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000800365
# Company info: {'name': 'FUJI PHOTO FILM CO LTD /FI', 'cik': '0000800365', 'ticker': ['FUJIY', 'FUJIF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001070304
# Company info: {'name': 'ORIX CORP', 'cik': '0001070304', 'ticker': ['IX', 'ORXCF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000936340
# Company info: {'name': 'DTE ENERGY CO', 'cik': '0000936340', 'ticker': ['DTE', 'DTW', 'DTG', 'DTB']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001601712
# Company info: {'name': 'Synchrony Financial', 'cik': '0001601712', 'ticker': ['SYF', 'SYF-PB', 'SYF-PA']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0002018139
# Company info: {'name': 'Toyota Tsusho Corporation/ADR', 'cik': '0002018139', 'ticker': ['TYHOY', 'TYHOF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000011544
# Company info: {'name': 'BERKLEY W R CORP', 'cik': '0000011544', 'ticker': ['WRB', 'WRB-PE', 'WRB-PF', 'WRB-PG', 'WRB-PH']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001992829
# Company info: {'name': 'SANDOZ GROUP AG', 'cik': '0001992829', 'ticker': ['SDZNY', 'SDZXF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000717826
# Company info: {'name': 'ERICSSON LM TELEPHONE CO', 'cik': '0000717826', 'ticker': ['ERIC', 'ERIXF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000313216
# Company info: {'name': 'KONINKLIJKE PHILIPS NV', 'cik': '0000313216', 'ticker': ['PHG', 'RYLPF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000049196
# Company info: {'name': 'HUNTINGTON BANCSHARES INC /MD/', 'cik': '0000049196', 'ticker': ['HBAN', 'HBANL', 'HBANM', 'HBANP']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000798941
# Company info: {'name': 'FIRST CITIZENS BANCSHARES INC /DE/', 'cik': '0000798941', 'ticker': ['FCNCA', 'FCNCB', 'FCNCO', 'FCNCP']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001535759
# Company info: {'name': 'Kongsberg Gruppen ASA/ADR', 'cik': '0001535759', 'ticker': ['KBGGY', 'NSKFF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001243429
# Company info: {'name': 'ArcelorMittal', 'cik': '0001243429', 'ticker': ['MT', 'AMSYF', 'ARCXF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000051434
# Company info: {'name': 'INTERNATIONAL PAPER CO /NEW/', 'cik': '0000051434', 'ticker': ['IP', 'INPAP']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001158967
# Company info: {'name': 'NIDEC CORP', 'cik': '0001158967', 'ticker': ['NJDCY', 'NNDNF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001754301
# Company info: {'name': 'Fox Corp', 'cik': '0001754301', 'ticker': ['FOXA', 'FOX']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001666175
# Company info: {'name': 'Fortis Inc.', 'cik': '0001666175', 'ticker': ['FTS', 'FORFF', 'FTRSF', 'FRTSF', 'FTPSF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000073124
# Company info: {'name': 'NORTHERN TRUST CORP', 'cik': '0000073124', 'ticker': ['NTRS', 'NTRSO']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001989183
# Company info: {'name': 'DSM-Firmenich AG/ADR', 'cik': '0001989183', 'ticker': ['DSFIY', 'DSMFF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001474968
# Company info: {'name': 'Geely Automobile Holdings Limited/ADR', 'cik': '0001474968', 'ticker': ['GELHY', 'GELYF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000932787
# Company info: {'name': 'STMicroelectronics N.V.', 'cik': '0000932787', 'ticker': ['STM', 'STMEF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000701818
# Company info: {'name': 'KINROSS GOLD CORP', 'cik': '0000701818', 'ticker': ['KGC', 'KGCRF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001281761
# Company info: {'name': 'REGIONS FINANCIAL CORP', 'cik': '0001281761', 'ticker': ['RF', 'RF-PC', 'RF-PE', 'RF-PF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001527166
# Company info: {'name': 'Carlyle Group Inc.', 'cik': '0001527166', 'ticker': ['CG', 'CGABL']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001050952
# Company info: {'name': 'PUBLICIS GROUPE SA', 'cik': '0001050952', 'ticker': ['PUBGY', 'PGPEF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000718940
# Company info: {'name': 'BCE INC', 'cik': '0000718940', 'ticker': ['BCE', 'BECEF', 'BCEFF', 'BCEPF', 'BCEXF', 'BCENF', 'BCEIF', 'BCPPF', 'BCAEF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001880661
# Company info: {'name': 'TPG Inc.', 'cik': '0001880661', 'ticker': ['TPG', 'TPGXL']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000924613
# Company info: {'name': 'NOKIA CORP', 'cik': '0000924613', 'ticker': ['NOK', 'NOKBF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000895126
# Company info: {'name': 'EXPAND ENERGY Corp', 'cik': '0000895126', 'ticker': ['EXE', 'EXEEZ', 'EXEEW', 'EXEEL']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001447391
# Company info: {'name': 'RESONA HOLDINGS INC', 'cik': '0001447391', 'ticker': ['RSHGY', 'RSNHF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001126113
# Company info: {'name': 'TELENOR ASA', 'cik': '0001126113', 'ticker': ['TELNY', 'TELNF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000759944
# Company info: {'name': 'CITIZENS FINANCIAL GROUP INC/RI', 'cik': '0000759944', 'ticker': ['CFG', 'CFG-PE', 'CFG-PH', 'CFG-PI']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001546066
# Company info: {'name': 'PEMBINA PIPELINE CORP', 'cik': '0001546066', 'ticker': ['PBA', 'PPLOF', 'PBNAF', 'PMBPF', 'PMMBF', 'PPLAF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001791706
# Company info: {'name': 'Li Auto Inc.', 'cik': '0001791706', 'ticker': ['LI', 'LAAOF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000811156
# Company info: {'name': 'CMS ENERGY CORP', 'cik': '0000811156', 'ticker': ['CMS', 'CMSA', 'CMSC', 'CMSD', 'CMS-PC']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001446437
# Company info: {'name': 'Yahoo! Japan Corp', 'cik': '0001446437', 'ticker': ['YAHOY', 'YAHOF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001810997
# Company info: {'name': 'XPENG INC.', 'cik': '0001810997', 'ticker': ['XPEV', 'XPNGF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000091576
# Company info: {'name': 'KEYCORP /NEW/', 'cik': '0000091576', 'ticker': ['KEY', 'KEY-PJ', 'KEY-PK', 'KEY-PI', 'KEY-PL']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001163653
# Company info: {'name': 'NOMURA HOLDINGS INC', 'cik': '0001163653', 'ticker': ['NMR', 'NRSCF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000818686
# Company info: {'name': 'TEVA PHARMACEUTICAL INDUSTRIES LTD', 'cik': '0000818686', 'ticker': ['TEVA', 'TEVJF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0002013003
# Company info: {'name': 'Pro Medicus Ltd./ADR', 'cik': '0002013003', 'ticker': ['PMDIY', 'PMCUF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001617640
# Company info: {'name': 'ZILLOW GROUP, INC.', 'cik': '0001617640', 'ticker': ['ZG', 'Z']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001142231
# Company info: {'name': 'HEINEKEN HOLDING N V', 'cik': '0001142231', 'ticker': ['HKHHY', 'HKHHF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001855612
# Company info: {'name': 'Grab Holdings Ltd', 'cik': '0001855612', 'ticker': ['GRAB', 'GRABW']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001748790
# Company info: {'name': 'Amcor plc', 'cik': '0001748790', 'ticker': ['AMCR', 'AMCCF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000733099
# Company info: {'name': 'ROGERS COMMUNICATIONS INC', 'cik': '0000733099', 'ticker': ['RCI', 'RCIAF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001190723
# Company info: {'name': 'TENARIS SA', 'cik': '0001190723', 'ticker': ['TS', 'TNRSF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000063754
# Company info: {'name': 'MCCORMICK & CO INC', 'cik': '0000063754', 'ticker': ['MKC', 'MKC-V']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001889539
# Company info: {'name': 'Corebridge Financial, Inc.', 'cik': '0001889539', 'ticker': ['CRBG', 'CRBD']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000849399
# Company info: {'name': 'Gen Digital Inc.', 'cik': '0000849399', 'ticker': ['GEN', 'GENVR']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000858446
# Company info: {'name': 'INTERCONTINENTAL HOTELS GROUP PLC /NEW/', 'cik': '0000858446', 'ticker': ['IHG', 'ICHGF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001039610
# Company info: {'name': 'EDP ENERGIAS DE PORTUGAL SA', 'cik': '0001039610', 'ticker': ['EDPFY', 'ELCPF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001439124
# Company info: {'name': 'BRAZILIAN ELECTRIC POWER CO', 'cik': '0001439124', 'ticker': ['EBR', 'EBR-B']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000882602
# Company info: {'name': 'OMV AKTIENGESELLSCHAFT /FI', 'cik': '0000882602', 'ticker': ['OMVKY', 'OMVJF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000910631
# Company info: {'name': 'COCA COLA FEMSA SAB DE CV', 'cik': '0000910631', 'ticker': ['KOF', 'COCSF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001564708
# Company info: {'name': 'NEWS CORP', 'cik': '0001564708', 'ticker': ['NWSA', 'NWS', 'NWSAL']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000912595
# Company info: {'name': 'MID AMERICA APARTMENT COMMUNITIES INC.', 'cik': '0000912595', 'ticker': ['MAA', 'MAA-PI']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000105016
# Company info: {'name': 'WATSCO INC', 'cik': '0000105016', 'ticker': ['WSO', 'WSO-B']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001533232
# Company info: {'name': 'Brookfield Renewable Partners L.P.', 'cik': '0001533232', 'ticker': ['BEP', 'BEPH', 'BEPI', 'BEP-PA', 'BRENF', 'BEPJ']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000845982
# Company info: {'name': 'SMITH & NEPHEW PLC', 'cik': '0000845982', 'ticker': ['SNN', 'SNNUF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001333986
# Company info: {'name': 'Equitable Holdings, Inc.', 'cik': '0001333986', 'ticker': ['EQH', 'EQH-PA', 'EQH-PC']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000886986
# Company info: {'name': 'TECK RESOURCES LTD', 'cik': '0000886986', 'ticker': ['TECK', 'TCKRF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0002019040
# ...
#
# CIK: 0001091587
# Company info: {'name': 'ABB LTD', 'cik': '0001091587', 'ticker': ['ABLZF', 'ABBNY']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000769594
# Company info: {'name': 'NIPPON TELEGRAPH & TELEPHONE CORP', 'cik': '0000769594', 'ticker': ['NTTYY', 'NPPXF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000030554
# Company info: {'name': 'EIDP, Inc.', 'cik': '0000030554', 'ticker': ['CTA-PB', 'CTA-PA']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000719245
# Company info: {'name': 'WESTPAC BANKING CORP', 'cik': '0000719245', 'ticker': ['WEBNF', 'WBKCY']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001038143
# Company info: {'name': 'ORANGE', 'cik': '0001038143', 'ticker': ['FNCTF', 'ORANY']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000016988
# Company info: {'name': 'CANON INC', 'cik': '0000016988', 'ticker': ['CAJPY', 'CAJFF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001560385
# Company info: {'name': 'Liberty Media Corp', 'cik': '0001560385', 'ticker': ['FWONK', 'FWONA', 'FWONB']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001712356
# Company info: {'name': 'Hydro One Ltd', 'cik': '0001712356', 'ticker': ['HRNNF', 'HYNLY']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001030475
# Company info: {'name': 'CHINA EASTERN AIRLINES CORP LTD', 'cik': '0001030475', 'ticker': ['CHEAF', 'CHNEY']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001447100
# Company info: {'name': 'Yamaha Motor Co., Ltd.', 'cik': '0001447100', 'ticker': ['YAMHF', 'YMHAY']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001792045
# Company info: {'name': 'Technip Energies N.V.', 'cik': '0001792045', 'ticker': ['THNPY', 'THNPF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001527469
# Company info: {'name': 'Athene Holding Ltd.', 'cik': '0001527469', 'ticker': ['ATH-PA', 'ATHS', 'ATH-PB', 'ATH-PD', 'ATH-PE']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001156831
# Company info: {'name': 'QUEBECOR MEDIA INC', 'cik': '0001156831', 'ticker': ['QBCRF', 'QBCAF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001695519
# Company info: {'name': 'AltaGas Ltd.', 'cik': '0001695519', 'ticker': ['ATGFF', 'ATGAF', 'ATGPF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001792627
# Company info: {'name': 'Just Eat Takeaway.com N.V.', 'cik': '0001792627', 'ticker': ['TKAYF', 'JTKWY']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0002021938
# Company info: {'name': 'Sunrise Communications AG', 'cik': '0002021938', 'ticker': ['SNRE', 'SNNRF', 'SNRBY', 'SNREY']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001536787
# Company info: {'name': 'ALSOK Co Ltd./ADR', 'cik': '0001536787', 'ticker': ['SOHGY', 'SOHGF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000092108
# Company info: {'name': 'SOUTHERN CALIFORNIA GAS CO', 'cik': '0000092108', 'ticker': ['SOCGP', 'SOCGM']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001660734
# Company info: {'name': 'Triton International Ltd', 'cik': '0001660734', 'ticker': ['TRTN-PA', 'TRTN-PB', 'TRTN-PC', 'TRTN-PD', 'TRTN-PE', 'TRTN-PF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000107815
# Company info: {'name': 'WISCONSIN ELECTRIC POWER CO', 'cik': '0000107815', 'ticker': ['WELPP', 'WELPM']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001412100
# Company info: {'name': 'Maiden Holdings, Ltd.', 'cik': '0001412100', 'ticker': ['MHLA', 'MHNC']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001598655
# Company info: {'name': 'GasLog Partners LP', 'cik': '0001598655', 'ticker': ['GLOP-PB', 'GLOP-PC', 'GLOP-PA']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001452857
# Company info: {'name': 'STEEL PARTNERS HOLDINGS L.P.', 'cik': '0001452857', 'ticker': ['SPLP', 'SPLPP']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000023426
# Company info: {'name': 'CONNECTICUT LIGHT & POWER CO', 'cik': '0000023426', 'ticker': ['CNTHP', 'CNLPL', 'CNTHO', 'CNTHN', 'CNLHO', 'CNLHP', 'CNLTP', 'CNLTL', 'CNPWM', 'CNPWP', 'CNLPM', 'CNLTN', 'CNLHN']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001839998
# Company info: {'name': 'American Oncology Network, Inc.', 'cik': '0001839998', 'ticker': ['AONC', 'AONCW']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000761648
# Company info: {'name': 'CEDAR REALTY TRUST, INC.', 'cik': '0000761648', 'ticker': ['CDR-PB', 'CDR-PC']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001814974
# Company info: {'name': 'BBX Capital, Inc.', 'cik': '0001814974', 'ticker': ['BBXIB', 'BBXIA']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001854078
# Company info: {'name': 'Relief Therapeutics Holding SA', 'cik': '0001854078', 'ticker': ['RLFTF', 'RLFTY']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001101026
# Company info: {'name': 'Zivo Bioscience, Inc.', 'cik': '0001101026', 'ticker': ['ZIVO', 'ZIVOW']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001389207
# Company info: {'name': 'Gafisa S.A.', 'cik': '0001389207', 'ticker': ['GFASY', 'GFSAY']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001445654
# Company info: {'name': 'New Zealand Oil & Gas Ltd/ADR', 'cik': '0001445654', 'ticker': ['NZEOF', 'NZEOY']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001865861
# Company info: {'name': 'Cactus Acquisition Corp. 1 Ltd', 'cik': '0001865861', 'ticker': ['CCTSF', 'CTSUF', 'CTSWF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001175483
# Company info: {'name': 'Drive Shack Inc.', 'cik': '0001175483', 'ticker': ['DSHK', 'DSHKN', 'DSHKO', 'DSHKP']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001811115
# Company info: {'name': 'Renalytix plc', 'cik': '0001811115', 'ticker': ['RNLXY', 'RENXF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001376986
# Company info: {'name': 'Tennessee Valley Authority', 'cik': '0001376986', 'ticker': ['TVE', 'TVC']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000707388
# Company info: {'name': 'STAR EQUITY HOLDINGS, INC.', 'cik': '0000707388', 'ticker': ['STRR', 'STRRP']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001357671
# Company info: {'name': 'Creatd, Inc.', 'cik': '0001357671', 'ticker': ['CRTD', 'CRTDW']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001852633
# Company info: {'name': 'Pinstripes Holdings, Inc.', 'cik': '0001852633', 'ticker': ['PNST', 'PNSTW']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001964630
# Company info: {'name': 'Vast Renewables Ltd', 'cik': '0001964630', 'ticker': ['VSTTF', 'VSTWF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001785592
# Company info: {'name': 'Leafly Holdings, Inc. /DE', 'cik': '0001785592', 'ticker': ['LFLY', 'LFLYW']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001451448
# Company info: {'name': 'ESPORTS ENTERTAINMENT GROUP, INC.', 'cik': '0001451448', 'ticker': ['GMBL', 'GMBLP', 'GMBLZ']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001903464
# Company info: {'name': 'Aimfinity Investment Corp. I', 'cik': '0001903464', 'ticker': ['AIMTF', 'AIMWF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001554625
# Company info: {'name': 'Priority Income Fund, Inc.', 'cik': '0001554625', 'ticker': ['PRIF-PD', 'PRIF-PJ', 'PRIF-PK', 'PRIF-PL']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001087711
# Company info: {'name': 'Santander UK plc', 'cik': '0001087711', 'ticker': ['STNDF', 'SNTUF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001114446
# Company info: {'name': 'UBS AG', 'cik': '0001114446', 'ticker': ['AMUB', 'BDCX', 'BDCZ', 'CEFD', 'CEFZ', 'UCIB', 'USML', 'SMHB', 'MTUL', 'MVRL', 'PFFL', 'QULL', 'SCDL', 'IWFL', 'IWML', 'MLPB', 'MLPR', 'HDLB', 'IFED', 'IWDL']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001610940
# Company info: {'name': 'Amplify Commodity Trust', 'cik': '0001610940', 'ticker': ['BDRY', 'BWET']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001496254
# Company info: {'name': 'Alternative Strategies Income Fund', 'cik': '0001496254', 'ticker': ['LTAFX', 'LTCFX']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000312070
# Company info: {'name': 'BARCLAYS BANK PLC', 'cik': '0000312070', 'ticker': ['ATMP', 'BWVTF', 'DJP', 'GBUG', 'GRN', 'VXX', 'VXZ', 'JJETF', 'TAPR']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001692345
# Company info: {'name': 'PROCACCIANTI HOTEL REIT, INC.', 'cik': '0001692345', 'ticker': ['PRXK', 'PRXA']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001690536
# Company info: {'name': 'FS Credit Real Estate Income Trust, Inc.', 'cik': '0001690536', 'ticker': ['FSREM', 'FSREI']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000092103
# Company info: {'name': 'SOUTHERN CALIFORNIA EDISON Co', 'cik': '0000092103', 'ticker': ['SCE-PN', 'SCE-PM', 'SCE-PG', 'SCE-PJ', 'SCE-PK', 'SCE-PL']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001308106
# Company info: {'name': 'Seapeak LLC', 'cik': '0001308106', 'ticker': ['SEAL-PB', 'SEAL-PA']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001333172
# Company info: {'name': 'Navios Maritime Holdings Inc.', 'cik': '0001333172', 'ticker': ['NMPGY', 'NMPRY']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001091748
# Company info: {'name': 'Argo Group International Holdings, Inc.', 'cik': '0001091748', 'ticker': ['ARGD', 'ARGO-PA']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001451561
# Company info: {'name': 'Schibsted ASA / ADR', 'cik': '0001451561', 'ticker': ['SBBTF', 'SBSNF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001471824
# Company info: {'name': 'Teucrium Commodity Trust', 'cik': '0001471824', 'ticker': ['CANE', 'CORN', 'SOYB', 'TAGS', 'WEAT']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001415311
# Company info: {'name': 'ProShares Trust II', 'cik': '0001415311', 'ticker': ['AGQ', 'BOIL', 'EUO', 'GLL', 'KOLD', 'YCL', 'YCS', 'ZSL', 'UGL', 'ULE', 'UVXY', 'VIXM', 'VIXY', 'SCO', 'SVXY', 'UCO']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001053092
# Company info: {'name': 'CREDIT SUISSE AG', 'cik': '0001053092', 'ticker': ['GLDI', 'SLVO', 'USOI']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001039828
# Company info: {'name': 'American National Group Inc.', 'cik': '0001039828', 'ticker': ['ANG-PD', 'ANG-PB']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0000013372
# Company info: {'name': 'NSTAR ELECTRIC CO', 'cik': '0000013372', 'ticker': ['NSARO', 'NSARP']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001845149
# Company info: {'name': 'Chain Bridge I', 'cik': '0001845149', 'ticker': ['CBGGF', 'CBRGF', 'CBRRF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001506721
# Company info: {'name': 'Balfour Beatty plc/ADR', 'cik': '0001506721', 'ticker': ['BLFBY', 'BAFBF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001655190
# Company info: {'name': 'Schindler Holding AG/ADR', 'cik': '0001655190', 'ticker': ['SHLAF', 'SHLRF']}
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# CIK: 0001546538
# Company info: {'name': 'BTS Group Holdings Public Co Limited/ADR', 'cik': '0001546538', 'ticker': ['BTGRF', 'BTLWF']}
# ------------------------------------------------------------

# %%
name_to_cik
# Out:
# {'nvidia corp': '0001045810',
#  'microsoft corp': '0000789019',
#  'apple inc.': '0000320193',
#  'alphabet inc.': '0001652044',
#  'amazon com inc': '0001018724',
#  'meta platforms, inc.': '0001326801',
#  'broadcom inc.': '0001730168',
#  'tesla, inc.': '0001318605',
#  'berkshire hathaway inc': '0001067983',
#  'jpmorgan chase & co': '0000019617',
#  'walmart inc.': '0000104169',
#  'visa inc.': '0001403161',
#  'oracle corp': '0001341439',
#  'eli lilly & co': '0000059478',
#  'spdr s&p 500 etf trust': '0000884394',
#  'mastercard inc': '0001141391',
#  'netflix inc': '0001065280',
#  'exxon mobil corp': '0000034088',
#  'johnson & johnson': '0000200406',
#  'costco wholesale corp /new': '0000909832',
#  'home depot, inc.': '0000354950',
#  'bank of america corp /de/': '0000070858',
#  'palantir technologies inc.': '0001321655',
#  'abbvie inc.': '0001551152',
#  'procter & gamble co': '0000080424',
#  'sap se': '0001000184',
#  'chevron corp': '0000093410',
#  'asml holding nv': '0000937966',
#  'coca cola co': '0000021344',
#  'alibaba group holding ltd': '0001577552',
#  'general electric co': '0000040545',
#  't-mobile us, inc.': '0001283699',
#  'unitedhealth group inc': '0000731766',
#  'cisco systems, inc.': '0000858877',
#  'advanced micro devices inc': '0000002488',
#  'wells fargo & company/mn': '0000072971',
#  'novo nordisk a s': '0000353278',
#  'toyota motor corp/': '0001094517',
#  'philip morris international inc.': '0001413329',
#  'astrazeneca plc': '0000901832',
#  'novartis ag': '0001114448',
#  'morgan stanley': '0000895421',
#  'salesforce, inc.': '0001108524',
#  'abbott laboratories': '0000001800',
#  'international business machines corp': '0000051143',
#  'goldman sachs group inc': '0000886982',
#  'linde plc': '0001707925',
#  'invesco qqq trust, series 1': '0001067839',
#  'american express co': '0000004962',
#  'hsbc holdings plc': '0001089113',
#  'mcdonalds corp': '0000063908',
#  'shell plc': '0001306965',
#  'rtx corp': '0000101829',
#  'walt disney co': '0001744489',
#  'blackstone inc.': '0001393818',
#  'merck & co., inc.': '0000310158',
#  'at&t inc.': '0000732717',
#  'royal bank of canada': '0001000275',
#  'caterpillar inc': '0000018230',
#  'pepsico inc': '0000077476',
#  'uber technologies, inc': '0001543151',
#  'texas instruments inc': '0000097476',
#  'verizon communications inc': '0000732712',
#  'hdfc bank ltd': '0001144967',
#  'intuit inc.': '0000896878',
#  'thermo fisher scientific inc.': '0000097745',
#  'contemporary amperex technology co., limited/adr': '0002070829',
#  'servicenow, inc.': '0001373715',
#  'booking holdings inc.': '0001075531',
#  'deutsche telekom ag': '0000946770',
#  'shopify inc.': '0001594805',
#  'citigroup inc': '0000831001',
#  'boeing co': '0000012927',
#  'schwab charles corp': '0000316709',
#  'blackrock, inc.': '0002012383',
#  'mitsubishi ufj financial group inc': '0000067088',
#  'pdd holdings inc.': '0001737806',
#  'qualcomm inc/de': '0000804328',
#  'ge vernova inc.': '0001996810',
#  'intuitive surgical inc': '0001035267',
#  's&p global inc.': '0000064040',
#  'arista networks, inc.': '0001596532',
#  'sony group corp': '0000313838',
#  'accenture plc': '0001467373',
#  'boston scientific corp': '0000885725',
#  'applovin corp': '0001751008',
#  'amgen inc': '0000318154',
#  'unilever plc': '0000217410',
#  'tjx companies inc /de/': '0000109198',
#  'nextera energy inc': '0000753308',
#  'adobe inc.': '0000796343',
#  'stryker corp': '0000310764',
#  'arm holdings plc /uk': '0001973239',
#  'danaher corp /de/': '0000313616',
#  'lowes companies inc': '0000060667',
#  'capital one financial corp': '0000927628',
#  'progressive corp/oh/': '0000080661',
#  'pfizer inc': '0000078003',
#  'spotify technology s.a.': '0001639920',
#  'bhp group ltd': '0000811809',
#  'gilead sciences, inc.': '0000882095',
#  'honeywell international inc': '0000773840',
#  'banco santander, s.a.': '0000891478',
#  'totalenergies se': '0000879764',
#  'eaton corp plc': '0001551182',
#  'amphenol corp /de/': '0000820313',
#  'deere & co': '0000315189',
#  'micron technology inc': '0000723125',
#  'toronto dominion bank': '0000947263',
#  'union pacific corp': '0000100885',
#  'applied materials inc /de': '0000006951',
#  'kkr & co. inc.': '0001404912',
#  'lam research corp': '0000707549',
#  'ubs group ag': '0001610520',
#  'analog devices inc': '0000006281',
#  'british american tobacco p.l.c.': '0001303523',
#  'hitachi ltd': '0000047710',
#  'palo alto networks inc': '0001327567',
#  'comcast corp': '0001166691',
#  'anheuser-busch inbev sa/nv': '0001668717',
#  'sanofi': '0001121404',
#  'automatic data processing inc': '0000008670',
#  'conocophillips': '0001163165',
#  'mercadolibre inc': '0001099590',
#  'rio tinto ltd': '0000887028',
#  'medtronic plc': '0001613103',
#  'kla corp': '0000319201',
#  'icici bank ltd': '0001103838',
#  'nike, inc.': '0000320187',
#  'welltower inc.': '0000766704',
#  'altria group, inc.': '0000764180',
#  'synopsys inc': '0000883241',
#  'chubb ltd': '0000896159',
#  'sea ltd': '0001703399',
#  'intel corp': '0000050863',
#  'lockheed martin corp': '0000936468',
#  'crowdstrike holdings, inc.': '0001535527',
#  'sumitomo mitsui financial group, inc.': '0001022837',
#  'doordash, inc.': '0001792789',
#  'interactive brokers group, inc.': '0001381197',
#  'prologis, inc.': '0001045609',
#  'enbridge inc': '0000895728',
#  'banco bilbao vizcaya argentaria, s.a.': '0000842180',
#  'southern co': '0000092122',
#  'intercontinental exchange, inc.': '0001571949',
#  'marsh & mclennan companies, inc.': '0000062709',
#  'compagnie financiere richemont ag /fi': '0000948401',
#  'rio tinto plc': '0000863064',
#  'vertex pharmaceuticals inc / ma': '0000875320',
#  'starbucks corp': '0000829224',
#  'constellation energy corp': '0001868275',
#  'brookfield corp /on/': '0001001085',
#  'royal caribbean cruises ltd': '0000884887',
#  'cme group inc.': '0001156375',
#  'strategy inc': '0001050446',
#  'brookfield asset management ltd.': '0001937926',
#  'parker-hannifin corp': '0000076334',
#  'bristol myers squibb co': '0000014272',
#  'duke energy corp': '0001326160',
#  'american tower corp /ma/': '0001053507',
#  'hca healthcare, inc.': '0000860730',
#  'trane technologies plc': '0001466258',
#  'cadence design systems inc': '0000813672',
#  'robinhood markets, inc.': '0001783879',
#  'sherwin williams co': '0000089800',
#  'moodys corp /de/': '0001059556',
#  'cvs health corp': '0000064803',
#  'waste management inc': '0000823768',
#  'bp plc': '0000313807',
#  'dell technologies inc.': '0001571996',
#  'o reilly automotive inc': '0000898173',
#  'relx plc': '0000929869',
#  'general dynamics corp': '0000040533',
#  'bank of montreal /can/': '0000927971',
#  'cintas corp': '0000723254',
#  'netease, inc.': '0001110646',
#  'roblox corp': '0001315098',
#  'mckesson corp': '0000927653',
#  'ferrari n.v.': '0001648416',
#  'northrop grumman corp /de/': '0001133421',
#  '3m co': '0000066740',
#  'mizuho financial group inc': '0001335730',
#  'spdr gold trust': '0001222333',
#  'pnc financial services group, inc.': '0000713676',
#  'gsk plc': '0001131399',
#  'cigna group': '0001739940',
#  'ecolab inc.': '0000031462',
#  'coinbase global, inc.': '0001679788',
#  'mondelez international, inc.': '0001103982',
#  'newmont corp /de/': '0001164727',
#  'airbnb, inc.': '0001559720',
#  'aon plc': '0000315293',
#  'thomson reuters corp /can/': '0001075124',
#  'transdigm group inc': '0001260221',
#  'southern copper corp/': '0001001838',
#  'illinois tool works inc': '0000049826',
#  'apollo global management, inc.': '0001858681',
#  'motorola solutions, inc.': '0000068505',
#  'equinix inc': '0001101239',
#  'bank of nova scotia': '0000009631',
#  'midea group co., ltd./adr': '0002039784',
#  'arthur j. gallagher & co.': '0000354190',
#  'petrobras - petroleo brasileiro sa': '0001119639',
#  'crh public ltd co': '0000849395',
#  'us bancorp \\de\\': '0000036104',
#  'fiserv inc': '0000798354',
#  'emerson electric co': '0000032604',
#  'united parcel service inc': '0001090727',
#  'bank of new york mellon corp': '0001390777',
#  'republic services, inc.': '0001060391',
#  'marriott international inc /md/': '0001048286',
#  'infosys ltd': '0001067491',
#  'ing groep nv': '0001039765',
#  'johnson controls international plc': '0000833444',
#  'national grid plc': '0001004315',
#  'itau unibanco holding s.a.': '0001132597',
#  'cloudflare, inc.': '0001477333',
#  'howmet aerospace inc.': '0000004281',
#  'barclays plc': '0000312069',
#  'nu holdings ltd.': '0001691493',
#  'canadian imperial bank of commerce /can/': '0001045520',
#  'canadian pacific kansas city ltd/cn': '0000016875',
#  'bae systems plc /fi/': '0000895564',
#  'williams companies, inc.': '0000107263',
#  'autozone inc': '0000866787',
#  'agnico eagle mines ltd': '0000002809',
#  'elevance health, inc.': '0001156039',
#  'zoetis inc.': '0001555280',
#  'enterprise products partners l.p.': '0001061219',
#  'deutsche bank aktiengesellschaft': '0001159508',
#  'colgate palmolive co': '0000021665',
#  'eog resources inc': '0000821189',
#  'simon property group inc /de/': '0001063761',
#  'snowflake inc.': '0001640147',
#  'lloyds banking group plc': '0001160106',
#  'paypal holdings, inc.': '0001633917',
#  'vistra corp.': '0001692819',
#  'air products & chemicals, inc.': '0000002969',
#  'canadian natural resources ltd': '0001017413',
#  'hilton worldwide holdings inc.': '0001585689',
#  'marvell technology, inc.': '0001835632',
#  'bayerische motoren werke ag/adr': '0001446250',
#  'diageo plc': '0000835403',
#  'freeport-mcmoran inc': '0000831259',
#  'equinor asa': '0001140625',
#  'regeneron pharmaceuticals, inc.': '0000872589',
#  'ishares gold trust': '0001278680',
#  'travelers companies, inc.': '0000086312',
#  'te connectivity plc': '0001385157',
#  'norfolk southern corp': '0000702165',
#  'workday, inc.': '0001327811',
#  'united rentals, inc.': '0001067701',
#  'autodesk, inc.': '0000769397',
#  'axon enterprise, inc.': '0001069183',
#  'grayscale bitcoin trust etf': '0001588489',
#  'canadian national railway co': '0000016868',
#  'america movil sab de cv/': '0001129137',
#  'energy transfer lp': '0001276187',
#  'csx corp': '0000277948',
#  'american electric power co inc': '0000004904',
#  'truist financial corp': '0000092230',
#  'monster beverage corp': '0000865752',
#  'kinder morgan, inc.': '0001506307',
#  'natwest group plc': '0000844150',
#  'nxp semiconductors n.v.': '0001413447',
#  'fortinet, inc.': '0001262039',
#  'alnylam pharmaceuticals, inc.': '0001178670',
#  'ares management corp': '0001176948',
#  'digital realty trust, inc.': '0001297996',
#  'carrier global corp': '0001783180',
#  'aflac inc': '0000004977',
#  'corning inc /ny': '0000024741',
#  'fastenal co': '0000815556',
#  'chipotle mexican grill inc': '0001058090',
#  'quanta services, inc.': '0001050915',
#  'roper technologies inc': '0000882835',
#  'advantest corp': '0001158838',
#  'cencora, inc.': '0001140859',
#  'general motors co': '0001467858',
#  'becton dickinson & co': '0000010795',
#  'cummins inc': '0000026172',
#  'infineon technologies ag': '0001107457',
#  'fedex corp': '0001048911',
#  'nasdaq, inc.': '0001120193',
#  'metlife inc': '0001099219',
#  'marathon petroleum corp': '0001510295',
#  'eni spa': '0001002242',
#  'flutter entertainment plc': '0001635327',
#  'allstate corp': '0000899051',
#  'phillips 66': '0001534701',
#  'sempra': '0001032208',
#  'schlumberger limited/nv': '0000087347',
#  'realty income corp': '0000726728',
#  'tc energy corp': '0001232384',
#  'paccar inc': '0000075362',
#  'cheniere energy, inc.': '0000003570',
#  'l3harris technologies, inc. /de/': '0000202058',
#  'coupang, inc.': '0001834584',
#  'manulife financial corp': '0001086888',
#  'dominion energy, inc': '0000715957',
#  'idexx laboratories inc /de': '0000874716',
#  'mplx lp': '0001552000',
#  'public storage': '0001393311',
#  'corteva, inc.': '0001755672',
#  'horton d r inc /de/': '0000882184',
#  'paychex inc': '0000723531',
#  'suncor energy inc': '0000311337',
#  'vertiv holdings co': '0001674101',
#  'ross stores, inc.': '0000745732',
#  'ameriprise financial inc': '0000820027',
#  'cbre group, inc.': '0001138118',
#  'w.w. grainger, inc.': '0000277135',
#  'block, inc.': '0001512673',
#  'pt chandra asri petrochemical tbk/adr': '0001547873',
#  'e.on se': '0001136808',
#  'veeva systems inc': '0001393052',
#  'edwards lifesciences corp': '0001099800',
#  'ford motor co': '0000037996',
#  'oneok inc /new/': '0001039684',
#  'coreweave, inc.': '0001769628',
#  'ferguson enterprises inc. /de/': '0002011641',
#  'copart inc': '0000900075',
#  'valero energy corp/tx': '0001035002',
#  'waste connections, inc.': '0001318220',
#  'takeda pharmaceutical co ltd': '0001395064',
#  'occidental petroleum corp /de/': '0000797468',
#  'imperial oil ltd': '0000049938',
#  'american international group, inc.': '0000005272',
#  'datadog, inc.': '0001561550',
#  'garmin ltd': '0001121788',
#  'barrick mining corp': '0000756894',
#  'honda motor co ltd': '0000715153',
#  'exelon corp': '0001109357',
#  'atlassian corp': '0001650372',
#  'jd.com, inc.': '0001549802',
#  'kroger co': '0000056873',
#  'target corp': '0000027419',
#  'baker hughes co': '0001701605',
#  'haleon plc': '0001900304',
#  'msci inc.': '0001408198',
#  'crown castle inc.': '0001051470',
#  'vale s.a.': '0000917851',
#  'carnival corp': '0000815097',
#  'wheaton precious metals corp.': '0001323404',
#  'carvana co.': '0001690820',
#  'argenx se': '0001697862',
#  'electronic arts inc.': '0000712515',
#  'ametek inc/': '0001037868',
#  'trip.com group ltd': '0001269238',
#  'kimberly clark corp': '0000055785',
#  'xcel energy inc': '0000072903',
#  'ebay inc': '0001065088',
#  'take two interactive software inc': '0000946581',
#  'diamondback energy, inc.': '0001539838',
#  'zscaler, inc.': '0001713683',
#  'monolithic power systems inc': '0001280452',
#  'public service enterprise group inc': '0000788784',
#  'resmed inc': '0000943819',
#  'galderma group ag/adr': '0002021390',
#  'coca-cola europacific partners plc': '0001650107',
#  'yum brands inc': '0001041061',
#  'alcon inc': '0001167379',
#  'keurig dr pepper inc.': '0001418135',
#  'delta air lines, inc.': '0000027904',
#  'entergy corp /de/': '0000065984',
#  'kenvue inc.': '0001944048',
#  'ferrovial se': '0001468522',
#  'reddit, inc.': '0001713445',
#  'tencent music entertainment group': '0001744676',
#  'rockwell automation, inc': '0001024478',
#  'las vegas sands corp': '0001300514',
#  'rocket companies, inc.': '0001805284',
#  'heico corp': '0000046619',
#  'prudential financial inc': '0001137774',
#  'banco santander (brasil) s.a.': '0001471055',
#  'live nation entertainment, inc.': '0001335258',
#  'vulcan materials co': '0001396009',
#  'sysco corp': '0000096021',
#  'fairfax financial holdings ltd/ can': '0000915191',
#  'costar group, inc.': '0001057352',
#  'carnival plc': '0001125259',
#  'hartford insurance group, inc.': '0000874766',
#  'verisk analytics, inc.': '0001442145',
#  'martin marietta materials inc': '0000916076',
#  'spdr dow jones industrial average etf trust': '0001041130',
#  'great-west lifeco inc.': '0000850918',
#  'hershey co': '0000047111',
#  'charter communications, inc. /mo/': '0001091667',
#  'fidelity national information services, inc.': '0001136893',
#  'beone medicines ltd.': '0001651308',
#  'jbs n.v.': '0001791942',
#  'consolidated edison inc': '0001047862',
#  'vici properties inc.': '0001705696',
#  'microchip technology inc': '0000827054',
#  'humana inc': '0000049071',
#  'targa resources corp.': '0001389170',
#  'franco nevada corp': '0001456346',
#  'seagate technology holdings plc': '0001137789',
#  'cardinal health inc': '0000721371',
#  'cognizant technology solutions corp': '0001058290',
#  'xylem inc.': '0001524472',
#  'mexican economic development inc': '0001061736',
#  'ambev s.a.': '0001565025',
#  'wec energy group, inc.': '0000783325',
#  'nucor corp': '0000073309',
#  'otis worldwide corp': '0001781335',
#  'lennar corp /new/': '0000920760',
#  'arch capital group ltd.': '0000947484',
#  'chocoladefabriken lindt & spruengli ag/adr': '0001885110',
#  'chunghwa telecom co ltd': '0001132924',
#  'fair isaac corp': '0000814547',
#  'figma, inc.': '0001579878',
#  'ge healthcare technologies inc.': '0001932393',
#  'united airlines holdings, inc.': '0000100517',
#  'agilent technologies, inc.': '0001090872',
#  'prudential plc': '0001116578',
#  'woodside energy group ltd': '0000844551',
#  'raymond james financial inc': '0000720005',
#  'westinghouse air brake technologies corp': '0000943452',
#  'estee lauder companies inc': '0001001250',
#  'ryanair holdings plc': '0001038683',
#  'pg&e corp': '0001004980',
#  'spdr s&p midcap 400 etf trust': '0000936958',
#  'tractor supply co /de/': '0000916365',
#  'cameco corp': '0001009001',
#  'kraft heinz co': '0001637459',
#  'state street corp': '0000093751',
#  'dupont de nemours, inc.': '0001666700',
#  'sun life financial inc': '0001097362',
#  'willis towers watson plc': '0001140536',
#  'old dominion freight line, inc.': '0000878927',
#  'ingersoll rand inc.': '0001699150',
#  'eqt corp': '0000033213',
#  'iqvia holdings inc.': '0001478242',
#  'brown & brown, inc.': '0000079282',
#  'circle internet group, inc.': '0001876042',
#  'venture global, inc.': '0002007855',
#  'ubiquiti inc.': '0001511737',
#  'm&t bank corp': '0000036270',
#  'extra space storage inc.': '0001289490',
#  'ventas, inc.': '0000740260',
#  'cenovus energy inc.': '0001475260',
#  'wipro ltd': '0001123799',
#  'baidu, inc.': '0001329099',
#  'equifax inc': '0000033185',
#  'telefonica s a': '0000814052',
#  'broadridge financial solutions, inc.': '0001383312',
#  'fifth third bancorp': '0000035527',
#  'archer-daniels-midland co': '0000007084',
#  'dexcom inc': '0001093557',
#  'sofi technologies, inc.': '0001818874',
#  'wolters kluwer n v /fi': '0000861967',
#  'hewlett packard enterprise co': '0001645590',
#  'bank bradesco': '0001160330',
#  'warner bros. discovery, inc.': '0001437107',
#  'astera labs, inc.': '0001736297',
#  'gold fields ltd': '0001172724',
#  'lpl financial holdings inc.': '0001397911',
#  'vodafone group public ltd co': '0000839923',
#  'fuji photo film co ltd /fi': '0000800365',
#  'orix corp': '0001070304',
#  'blue owl capital inc.': '0001823945',
#  'amrize ltd': '0002035989',
#  'dte energy co': '0000936340',
#  'nrg energy, inc.': '0001013871',
#  'restaurant brands international inc.': '0001618756',
#  'kb financial group inc.': '0001445930',
#  'symbotic inc.': '0001837240',
#  'nutrien ltd.': '0001725964',
#  'keysight technologies, inc.': '0001601046',
#  'insmed inc': '0001104506',
#  'synchrony financial': '0001601712',
#  'constellation brands, inc.': '0000016918',
#  'american water works company, inc.': '0001410636',
#  'stellantis n.v.': '0001605484',
#  'emcor group, inc.': '0000105634',
#  'anglogold ashanti plc': '0001973832',
#  'western digital corp': '0000106040',
#  'viking holdings ltd': '0001745201',
#  'kellanova': '0000055067',
#  'tradeweb markets inc.': '0001758730',
#  'toyota tsusho corporation/adr': '0002018139',
#  'avalonbay communities inc': '0000915912',
#  'rollins inc': '0000084839',
#  'ameren corp': '0001002910',
#  'berkley w r corp': '0000011544',
#  'iron mountain inc': '0001020569',
#  'ppl corp': '0000922224',
#  'sandoz group ag': '0001992829',
#  'atmos energy corp': '0000731802',
#  'veralto corp': '0001967680',
#  'super micro computer, inc.': '0001375365',
#  'ericsson lm telephone co': '0000717826',
#  'koninklijke philips nv': '0000313216',
#  'mettler toledo international inc/': '0001037646',
#  'cheniere energy partners, l.p.': '0001383650',
#  'expedia group, inc.': '0001324424',
#  'general mills inc': '0000040704',
#  'didi global inc.': '0001764757',
#  'huntington bancshares inc /md/': '0000049196',
#  'first citizens bancshares inc /de/': '0000798941',
#  'ptc inc.': '0000857005',
#  'kongsberg gruppen asa/adr': '0001535759',
#  'pultegroup inc/mi/': '0000822416',
#  'trade desk, inc.': '0001671933',
#  'toast, inc.': '0001650164',
#  'arcelormittal': '0001243429',
#  'equity residential': '0000906107',
#  'international paper co /new/': '0000051434',
#  'futu holdings ltd': '0001754581',
#  'hp inc': '0000047217',
#  'teledyne technologies inc': '0001094285',
#  'verisign inc/ca': '0001014473',
#  'ppg industries inc': '0000079879',
#  'firstenergy corp': '0001031296',
#  'nidec corp': '0001158967',
#  'fox corp': '0001754301',
#  'telus corp': '0000868675',
#  'affirm holdings, inc.': '0001820953',
#  'comfort systems usa inc': '0001035983',
#  'fortis inc.': '0001666175',
#  'northern trust corp': '0000073124',
#  'dsm-firmenich ag/adr': '0001989183',
#  'dover corp': '0000029905',
#  'cboe global markets, inc.': '0001374310',
#  'markel group inc.': '0001096343',
#  'biontech se': '0001776985',
#  'geely automobile holdings limited/adr': '0001474968',
#  'lululemon athletica inc.': '0001397187',
#  'pinterest, inc.': '0001506293',
#  'stmicroelectronics n.v.': '0000932787',
#  'hubspot inc': '0001404655',
#  'centerpoint energy inc': '0001130310',
#  'kinross gold corp': '0000701818',
#  'steris plc': '0001757898',
#  'regions financial corp': '0001281761',
#  'dollar general corp': '0000029534',
#  'zoom communications, inc.': '0001585521',
#  'tyler technologies inc': '0000860731',
#  'cincinnati financial corp': '0000020286',
#  'darden restaurants inc': '0000940944',
#  'price t rowe group inc': '0001113169',
#  'eversource energy': '0000072741',
#  'ulta beauty, inc.': '0001403568',
#  'smurfit westrock plc': '0002005951',
#  'mongodb, inc.': '0001441816',
#  'williams sonoma inc': '0000719955',
#  'hubbell inc': '0000048898',
#  'draftkings inc.': '0001883685',
#  'dollar tree, inc.': '0000935703',
#  'carlyle group inc.': '0001527166',
#  'leidos holdings, inc.': '0001336920',
#  'insulet corp': '0001145197',
#  'publicis groupe sa': '0001050952',
#  'bce inc': '0000718940',
#  'tpg inc.': '0001880661',
#  'nokia corp': '0000924613',
#  'labcorp holdings inc.': '0000920148',
#  'celestica inc': '0001030894',
#  'shinhan financial group co ltd': '0001263043',
#  'corpay, inc.': '0001175454',
#  'expand energy corp': '0000895126',
#  'amer sports, inc.': '0001988894',
#  'church & dwight co inc /de/': '0000313927',
#  'resona holdings inc': '0001447391',
#  'devon energy corp/de': '0001090012',
#  'telenor asa': '0001126113',
#  'sba communications corp': '0001034054',
#  'elbit systems ltd': '0001027664',
#  'natera, inc.': '0001604821',
#  'cyberark software ltd.': '0001598110',
#  'netapp, inc.': '0001002047',
#  'rocket lab corp': '0001819994',
#  'citizens financial group inc/ri': '0000759944',
#  'jabil inc': '0000898293',
#  'nvr inc': '0000906163',
#  'ke holdings inc.': '0001809587',
#  'pembina pipeline corp': '0001546066',
#  'aercap holdings n.v.': '0001378789',
#  'li auto inc.': '0001791706',
#  'ss&c technologies holdings inc': '0001402436',
#  'ase technology holding co., ltd.': '0001122411',
#  'cms energy corp': '0000811156',
#  'cdw corp': '0001402057',
#  'yahoo! japan corp': '0001446437',
#  'rb global inc.': '0001046102',
#  'cgi inc': '0001061574',
#  'edison international': '0000827052',
#  'credo technology group holding ltd': '0001807794',
#  'global payments inc': '0001123360',
#  'xpeng inc.': '0001810997',
#  'keycorp /new/': '0000091576',
#  'nomura holdings inc': '0001163653',
#  'zimmer biomet holdings, inc.': '0001136869',
#  'royalty pharma plc': '0001802768',
#  'tapestry, inc.': '0001116132',
#  'texas pacific land corp': '0001811074',
#  'teva pharmaceutical industries ltd': '0000818686',
#  'capitec bank holdings ltd / adr': '0001469059',
#  'first solar, inc.': '0001274494',
#  'on semiconductor corp': '0001097864',
#  'telefonica brasil s.a.': '0001066119',
#  'godaddy inc.': '0001609711',
#  'pro medicus ltd./adr': '0002013003',
#  'tyson foods, inc.': '0000100493',
#  'check point software technologies ltd': '0001015922',
#  'zillow group, inc.': '0001617640',
#  'heineken holding n v': '0001142231',
#  'samsara inc.': '0001642896',
#  'grab holdings ltd': '0001855612',
#  'flex ltd.': '0000866374',
#  'quest diagnostics inc': '0001022079',
#  'credicorp ltd': '0001001290',
#  'loews corp': '0000060086',
#  'biogen inc.': '0000875045',
#  'nisource inc.': '0001111711',
#  'lennox international inc': '0001069202',
#  'pure storage, inc.': '0001474432',
#  'amcor plc': '0001748790',
#  'trimble inc.': '0000864749',
#  'steel dynamics inc': '0001022671',
#  'perusahaan perseroan persero pt telekomunikasi indonesia tbk': '0001001807',
#  'rogers communications inc': '0000733099',
#  'genuine parts co': '0000040987',
#  'invitation homes inc.': '0001687229',
#  'halliburton co': '0000045012',
#  'packaging corp of america': '0000075677',
#  'ecopetrol s.a.': '0001444406',
#  'tenaris sa': '0001190723',
#  'mccormick & co inc': '0000063754',
#  'corebridge financial, inc.': '0001889539',
#  'gen digital inc.': '0000849399',
#  'weyerhaeuser co': '0000106535',
#  'globalfoundries inc.': '0001709048',
#  'teradyne, inc': '0000097210',
#  'nutanix, inc.': '0001618732',
#  'intercontinental hotels group plc /new/': '0000858446',
#  'brookfield wealth solutions ltd.': '0001837429',
#  'edp energias de portugal sa': '0001039610',
#  'gartner inc': '0000749251',
#  'caseys general stores inc': '0000726958',
#  'curtiss wright corp': '0000026324',
#  'essex property trust, inc.': '0000920522',
#  'brazilian electric power co': '0001439124',
#  'summit therapeutics inc.': '0001599298',
#  'coterra energy inc.': '0000858470',
#  'erie indemnity co': '0000922621',
#  'omv aktiengesellschaft /fi': '0000882602',
#  'guidewire software, inc.': '0001528396',
#  'f5, inc.': '0001048695',
#  "dick's sporting goods, inc.": '0001089063',
#  'lyondellbasell industries n.v.': '0001489393',
#  'coca cola femsa sab de cv': '0000910631',
#  'principal financial group inc': '0001126328',
#  'pentair plc': '0000077360',
#  'gfl environmental inc.': '0001780232',
#  'joint stock co kaspi.kz': '0001985487',
#  'ralph lauren corp': '0001037038',
#  'somnigroup international inc.': '0001206264',
#  'burlington stores, inc.': '0001579298',
#  'jacobs solutions inc.': '0000052988',
#  'west pharmaceutical services inc': '0000105770',
#  'warner music group corp.': '0001319161',
#  'ast spacemobile, inc.': '0001780312',
#  'waters corp /de/': '0001000697',
#  'news corp': '0001564708',
#  'us foods holding corp.': '0001665918',
#  'dow inc.': '0001751788',
#  'southwest airlines co': '0000092380',
#  'talen energy corp': '0001622536',
#  'aptiv plc': '0001521332',
#  'mid america apartment communities inc.': '0000912595',
#  'deckers outdoor corp': '0000910521',
#  'transunion': '0001552033',
#  'snap-on inc': '0000091440',
#  'korea electric power corp': '0000887225',
#  'international flavors & fragrances inc': '0000051253',
#  'united microelectronics corp': '0001033767',
#  'rubrik, inc.': '0001943896',
#  'unity software inc.': '0001810806',
#  'bunge global sa': '0001996862',
#  'sharkninja, inc.': '0001957132',
#  'alliant energy corp': '0000352541',
#  'carlisle companies inc': '0000790051',
#  'chewy, inc.': '0001766502',
#  'watsco inc': '0000105016',
#  'echostar corp': '0001415404',
#  'brookfield renewable partners l.p.': '0001533232',
#  'aecom': '0000868857',
#  'nebius group n.v.': '0001513845',
#  'evergy, inc.': '0001711269',
#  'expeditors international of washington inc': '0000746515',
#  'bentley systems inc': '0001031308',
#  'fidelity national financial, inc.': '0001331875',
#  'laopu gold co. ltd./adr': '0002068440',
#  'incyte corp': '0000879169',
#  'fortive corp': '0001659166',
#  'sun communities inc': '0000912593',
#  'yum china holdings, inc.': '0001673358',
#  'zebra technologies corp': '0000877212',
#  'okta, inc.': '0001660134',
#  'smith & nephew plc': '0000845982',
#  'rpm international inc/de/': '0000110621',
#  'posco holdings inc.': '0000889132',
#  'tenet healthcare corp': '0000070318',
#  'equitable holdings, inc.': '0001333986',
#  'paramount skydance corp': '0002041610',
#  'rivian automotive, inc. / de': '0001874178',
#  'teck resources ltd': '0000886986',
#  'hormel foods corp /de/': '0000048465',
#  'performance food group co': '0001618673',
#  'best buy co inc': '0000764478',
#  'nippon sanso holdings corporation/adr': '0002019040',
#  'twilio inc': '0001447669',
#  'ares capital corp': '0001287750',
#  'illumina, inc.': '0001110803',
#  'xpo, inc.': '0001166003',
#  'builders firstsource, inc.': '0001316835',
#  'masco corp /de/': '0000062996',
#  'reliance, inc.': '0000861884',
#  'vodacom group ltd / adr': '0001468608',
#  'companhia de saneamento basico do estado de sao paulo-sabesp': '0001170858',
#  'celsius holdings, inc.': '0001341766',
#  'ftai aviation ltd.': '0001590364',
#  'dominos pizza inc': '0001286681',
#  'genmab a/s': '0001434265',
#  'tko group holdings, inc.': '0001973266',
#  'omnicom group inc.': '0000029989',
#  'ryan specialty holdings, inc.': '0001849253',
#  'bwx technologies, inc.': '0001486957',
#  'api group corp': '0001796209',
#  'logitech international s.a.': '0001032975',
#  'kimco realty corp': '0000879101',
#  'technipfmc plc': '0001681459',
#  'cnh industrial n.v.': '0001567094',
#  'c. h. robinson worldwide, inc.': '0001043277',
#  'docusign, inc.': '0001261333',
#  'dynatrace, inc.': '0001773383',
#  'woodward, inc.': '0000108312',
#  'american homes 4 rent': '0001562401',
#  'asr nederland n.v./adr': '0001719117',
#  'zto express (cayman) inc.': '0001677250',
#  'hologic inc': '0000859737',
#  'fresenius medical care ag': '0001333141',
#  'cooper companies, inc.': '0000711404',
#  'allegion plc': '0001579241',
#  'nvent electric plc': '0001720635',
#  'on holding ag': '0001858985',
#  'latam airlines group s.a.': '0001047716',
#  'udr, inc.': '0000074208',
#  'east west bancorp inc': '0001069157',
#  'western midstream partners, lp': '0001423902',
#  'w. p. carey inc.': '0001025378',
#  'brookfield infrastructure partners l.p.': '0001406234',
#  'duolingo, inc.': '0001562088',
#  'textron inc': '0000217346',
#  'jones lang lasalle inc': '0001037976',
#  'bank of chile': '0001161125',
#  'clorox co /de/': '0000021076',
#  'everest group, ltd.': '0001095073',
#  'graco inc': '0000042888',
#  'factset research systems inc': '0001013237',
#  'brown forman corp': '0000014693',
#  'mastec inc': '0000015615',
#  'ball corp': '0000009389',
#  'emera inc': '0001127248',
#  'centene corp': '0001071739',
#  'sartorius ag/adr': '0001715801',
#  'qxo, inc.': '0001236275',
#  'sprouts farmers market, inc.': '0001575515',
#  'coherent corp.': '0000820318',
#  'roku, inc': '0001428439',
#  'houlihan lokey, inc.': '0001302215',
#  'hunt j b transport services inc': '0000728535',
#  'cf industries holdings, inc.': '0001324404',
#  'alexandria real estate equities, inc.': '0001035443',
#  'united therapeutics corp': '0001082554',
#  'hyatt hotels corp': '0001468174',
#  'neurocrine biosciences inc': '0000914475',
#  'lincoln electric holdings inc': '0000059527',
#  'booz allen hamilton holding corp': '0001443646',
#  'gaming & leisure properties, inc.': '0001575965',
#  'itt inc.': '0000216228',
#  'icon plc': '0001060955',
#  'avery dennison corp': '0000008818',
#  'nio inc.': '0001736541',
#  'annaly capital management inc': '0001043219',
#  'jefferies financial group inc.': '0000096223',
#  'cna financial corp': '0000021175',
#  'franklin resources inc': '0000038777',
#  'medpace holdings, inc.': '0001668397',
#  'toll brothers, inc.': '0000794170',
#  'full truck alliance co. ltd.': '0001838413',
#  'ciena corp': '0000936395',
#  'woori financial group inc.': '0001264136',
#  'clean harbors inc': '0000822818',
#  'manhattan associates inc': '0001056696',
#  'regency centers corp': '0000910606',
#  'chemical & mining co of chile inc': '0000909037',
#  'magna international inc': '0000749098',
#  'grupo cibest s.a.': '0002058897',
#  'core & main, inc.': '0001856525',
#  'wynn resorts ltd': '0001174922',
#  'rakuten group, inc.': '0001294591',
#  'federal national mortgage association fannie mae': '0000310522',
#  'omega healthcare investors inc': '0000888491',
#  'lamar advertising co/new': '0001090425',
#  "bj's wholesale club holdings, inc.": '0001531152',
#  'viper energy, inc.': '0002074176',
#  'cemex sab de cv': '0001076378',
#  'reinsurance group of america inc': '0000898174',
#  'owens corning': '0001370946',
#  'ul solutions inc.': '0001901440',
#  'paycom software, inc.': '0001590955',
#  'doximity, inc.': '0001516513',
#  'tempus ai, inc.': '0001717115',
#  'rbc bearings inc': '0001324948',
#  'entegris inc': '0001101302',
#  'nordson corp': '0000072331',
#  'ally financial inc.': '0000040729',
#  'solventum corp': '0001964738',
#  'baxter international inc': '0000010456',
#  'mp materials corp. / de': '0001801368',
#  'bxp, inc.': '0001037540',
#  'evercore inc.': '0001360901',
#  'alamos gold inc': '0001178819',
#  'idex corp /de/': '0000832101',
#  'aerovironment inc': '0001368622',
#  'aegon ltd.': '0000769218',
#  'encompass health corp': '0000785161',
#  'stantec inc': '0001131383',
#  'pacific airport group': '0001347557',
#  'plains all american pipeline lp': '0001070423',
#  'healthpeak properties, inc.': '0000765880',
#  'penske automotive group, inc.': '0001019849',
#  'joby aviation, inc.': '0001819848',
#  'ionq, inc.': '0001824920',
#  'mr. cooper group inc.': '0000933136',
#  'td synnex corp': '0001177394',
#  'ypf sociedad anonima': '0000904851',
#  'suzano s.a.': '0000909327',
#  'rentokil initial plc /fi': '0000930157',
#  'equity lifestyle properties inc': '0000895417',
#  'viatris inc': '0001792044',
#  'dutch bros inc.': '0001866581',
#  'sprott physical gold trust': '0001477049',
#  'host hotels & resorts, inc.': '0001070750',
#  'topbuild corp': '0001633931',
#  'dr reddys laboratories ltd': '0001135951',
#  'stifel financial corp': '0000720672',
#  'ishares silver trust': '0001330568',
#  'fabrinet': '0001408710',
#  'carpenter technology corp': '0000017843',
#  'pan american silver corp': '0000771992',
#  'sunny optical technology (group) co limited/adr': '0001601992',
#  'unum group': '0000005513',
#  'bloom energy corp': '0001664703',
#  'pool corp': '0000945841',
#  'snap inc': '0001564408',
#  'jack henry & associates inc': '0000779152',
#  'camden property trust': '0000906345',
#  'james hardie industries plc': '0001159152',
#  'zoominfo technologies inc.': '0001794515',
#  'ascendis pharma a/s': '0001612042',
#  'stanley black & decker, inc.': '0000093556',
#  'crown holdings, inc.': '0001219601',
#  'royal gold inc': '0000085535',
#  'universal health services inc': '0000352915',
#  'texas roadhouse, inc.': '0001289460',
#  'first horizon corp': '0000036966',
#  'renaissancere holdings ltd': '0000913144',
#  'kratos defense & security solutions, inc.': '0001069258',
#  'hasbro, inc.': '0000046080',
#  'globe life inc.': '0000320335',
#  'maplebear inc.': '0001579091',
#  'american financial group inc': '0001042046',
#  'permian resources corp': '0001658566',
#  'advanced drainage systems, inc.': '0001604028',
#  'sailpoint, inc.': '0002030781',
#  'daiwa securities group inc.': '0001481045',
#  'mobileye global inc.': '0001910139',
#  'skyworks solutions, inc.': '0000004127',
#  'biomarin pharmaceutical inc': '0001048477',
#  'deutsche lufthansa a g /fi': '0001049724',
#  'j m smucker co': '0000091419',
#  'norwegian cruise line holdings ltd.': '0001513761',
#  'crane co': '0001944013',
#  'sei investments co': '0000350894',
#  'banco santander chile': '0001027552',
#  'leonardo drs, inc.': '0001833756',
#  'essential utilities, inc.': '0000078128',
#  'service corp international': '0000089089',
#  'akamai technologies inc': '0001086222',
#  'morningstar, inc.': '0001289419',
#  'wesco international inc': '0000929008',
#  'westlake corp': '0001262823',
#  'dayforce, inc.': '0001725057',
#  'bunzl plc': '0001072397',
#  'generac holdings inc.': '0001474735',
#  'oklo inc.': '0001849056',
#  'h world group ltd': '0001483994',
#  'albertsons companies, inc.': '0001646972',
#  'assurant, inc.': '0001267238',
#  'huntington ingalls industries, inc.': '0001501585',
#  'caris life sciences, inc.': '0002019410',
#  'mgm resorts international': '0000789570',
#  'pinnacle west capital corp': '0000764622',
#  'caci international inc /de/': '0000016058',
#  'mueller industries inc': '0000089439',
#  'ovintiv inc.': '0001792580',
#  'pilgrims pride corp': '0000802481',
#  'kinsale capital group, inc.': '0001669162',
#  'pandora a/s / adr': '0001505880',
#  'mosaic co': '0001285785',
#  'freedom holding corp.': '0000924805',
#  'united utilities group plc': '0001440130',
#  'aurora innovation, inc.': '0001828108',
#  'ati inc': '0001018963',
#  'carrefour sa': '0001078642',
#  'red electrica corporacion sa/adr': '0001438654',
#  'penumbra inc': '0001321732',
#  'luckin coffee inc.': '0001767582',
#  'walgreens boots alliance, inc.': '0001618921',
#  'kanzhun ltd': '0001842827',
#  'webster financial corp': '0000801337',
#  'exelixis, inc.': '0000939767',
#  'dt midstream, inc.': '0001842022',
#  'aramark': '0001584509',
#  'qiagen n.v.': '0001015820',
#  'puig brands s.a./adr': '0002029472',
#  'lineage, inc.': '0001868159',
#  'align technology inc': '0001097149',
#  'southstate corp': '0000764038',
#  'nextracker inc.': '0001852131',
#  'carsales.com limited/adr': '0001541309',
#  'albemarle corp': '0000915913',
#  'nitori holdings co., ltd.': '0001801729',
#  'revvity, inc.': '0000031791',
#  'tim s.a.': '0001826168',
#  'acuity inc. (de)': '0001144215',
#  'rexford industrial realty, inc.': '0001571283',
#  'embraer s.a.': '0001355444',
#  'agnc investment corp.': '0001423689',
#  'coca-cola consolidated, inc.': '0000317540',
#  'regal rexnord corp': '0000082811',
#  'applied industrial technologies inc': '0000109563',
#  'smith a o corp': '0000091142',
#  'procore technologies, inc.': '0001611052',
#  'brookfield property partners l.p.': '0001545772',
#  'smithfield foods inc': '0000091388',
#  'molson coors beverage co': '0000024545',
#  'gamestop corp.': '0001326380',
#  'paylocity holding corp': '0001591698',
#  'hims & hers health, inc.': '0001773751',
#  'old republic international corp': '0000074260',
#  'u-haul holding co /nv/': '0000004457',
#  'appfolio inc': '0001433195',
#  'chime financial, inc.': '0001795586',
#  'ensign group, inc': '0001125376',
#  'invesco ltd.': '0000914208',
#  'davita inc.': '0000927066',
#  'interpublic group of companies, inc.': '0000051644',
#  'makemytrip ltd': '0001495153',
#  'western alliance bancorporation': '0001212545',
#  'kawasaki kisen kaisha ltd': '0001447126',
#  'southeast airport group': '0001123452',
#  'moderna, inc.': '0001682852',
#  'uwm holdings corp': '0001783398',
#  'new york times co': '0000071691',
#  'kt corp': '0000892450',
#  'tetra tech inc': '0000831641',
#  'antero resources corp': '0001433270',
#  'donaldson co inc': '0000029644',
#  'macom technology solutions holdings, inc.': '0001493594',
#  'epam systems, inc.': '0001352010',
#  'wayfair inc.': '0001616707',
#  'klaviyo, inc.': '0001835830',
#  "campbell's co": '0000016732',
#  'pearson plc': '0000938323',
#  'birkenstock holding plc': '0001977102',
#  'autoliv inc': '0001034670',
#  'amdocs ltd': '0001062579',
#  'aes corp': '0000874761',
#  'servicetitan, inc.': '0001638826',
#  'madrigal pharmaceuticals, inc.': '0001157601',
#  'watts water technologies inc': '0000795403',
#  'wingstop inc.': '0001636222',
#  'bridgebio pharma, inc.': '0001743881',
#  'spx technologies, inc.': '0000088205',
#  'primo brands corp': '0002042694',
#  'molina healthcare, inc.': '0001179929',
#  'skechers usa inc': '0001065837',
#  'harmony gold mining co ltd': '0001023514',
#  'borgwarner inc': '0000908255',
#  'bilibili inc.': '0001723690',
#  'hf sinclair corp': '0001915657',
#  'umb financial corp': '0000101382',
#  'carmax inc': '0001170010',
#  'cubesmart': '0001298675',
#  'bullish': '0001872195',
#  ...}

# %%
response = {
    "companies": [
        {
            "type": "cik",
            "value": "0001546538"
        },
        {
            "type": "name",
            "value": "apple inc."
        },
        {
            "type": "ticker",
            "value": "JPM"
        },
        {
            "type": "ticker",
            "value": "AAPL"
        }
    ],
    "financial_metrics": ["revenue", "gross_profit"],
    "time_period": ["last year", "2025", "Q3 2022"]
}

# the financial metrics are already standardised; so we don't need to touch them
# companies -> we need to standardise and retrieve company meta info

# If type == 'cik', then retrieve info from cik_to_metadata
# If type == 'name', then get cik from name_to_cik, then retrieve info from cik_to_metadata
# If type == 'ticker', then get cik from ticker_to_cik, then retrieve info from cik_to_metadata

extracted_company_entities = response.get("companies")
companies = []

for ent in extracted_company_entities:
    if ent["type"] == "cik":
        cik = ent["value"]
        companies.append(
            cik_to_metadata.get(cik, {})
        )
    elif ent["type"] == "name":
        # closest match of the name -> compare all keys with ent['value]
        match_value = ent["value"]
        cik = name_to_cik.get(match_value.lower(), None)
        companies.append(
            cik_to_metadata.get(cik, {})
        )
    elif ent["type"] == "ticker":
        match_value = ent["value"]
        cik = ticker_to_cik.get(match_value.lower(), None)
        companies.append(
            cik_to_metadata.get(cik, {})
        )

# %%
companies
# Out:
# [{'name': 'BTS Group Holdings Public Co Limited/ADR',
#   'cik': '0001546538',
#   'ticker': ['BTGRF', 'BTLWF']},
#  {'name': 'Apple Inc.', 'cik': '0000320193', 'ticker': ['AAPL']},
#  {'name': 'JPMORGAN CHASE & CO',
#   'cik': '0000019617',
#   'ticker': ['JPM',
#    'JPM-PC',
#    'JPM-PD',
#    'JPM-PJ',
#    'JPM-PK',
#    'JPM-PL',
#    'JPM-PM',
#    'VYLD',
#    'AMJB']},
#  {'name': 'Apple Inc.', 'cik': '0000320193', 'ticker': ['AAPL']}]
